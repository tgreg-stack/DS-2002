# %% [markdown]
# ## Demo 02: Using Python to Query MongoDB
# This notebook demonstrates additional MongoDB querying technicques using the **pymongo** library.  As it's name implies, pymongo is the MongoDB library for Python, and its **documentation** can be found here: https://pymongo.readthedocs.io/en/stable/index.html
#
# ### 1.0. Prerequisites
# This demonstration uses an instance of **MongoDB Atlas** *(the MongoDB cloud service)*; therefore, you must first create a **free** *(Shared)* instance of that service. This can be accomplished by following the instructions at: https://docs.atlas.mongodb.com/tutorial/create-new-cluster/.
#
# If you prefer to use a local instance of MongoDB then you will have to import the **trips.json** file to create the collection we will be working with.  This can either be accomplished using **MongoDB Compass**, or with sample code in the **Lab-04-Python-MongoDB-ETL** notebook.
#
# #### 1.1. Install the *pymongo* libary into your *python* environment by executing the following command in a *Terminal window*
# -  python -m pip install pymongo[srv]
#
# #### 1.2. Import the libaries that you'll be working with in the notebook

# %%
import os
import datetime
import pymongo
import pandas as pd

# %% [markdown]
# ### 2.0. Connecting to the MongoDB Instance

# %%
mongo_host_name = "localhost"
mongo_port = "27017"

atlas_cluster_name = "cluster0"
atlas_cluster_subnet = "rldhwbm"
atlas_default_dbname = "local"
atlas_user_name = "gfusion333_db_user"
atlas_password = "password"

# %%
conn_str = {
    "local" : f"mongodb://{mongo_host_name}:{mongo_port}/",
    "atlas" : f"mongodb+srv://{atlas_user_name}:{atlas_password}@{atlas_cluster_name}.{atlas_cluster_subnet}.mongodb.net/{atlas_default_dbname}"
}

client = pymongo.MongoClient(conn_str["atlas"])

print(f"Local Connection String: {conn_str['local']}")
print(f"Atlas Connection String: {conn_str['atlas']}")
# Out:
# Local Connection String: mongodb://localhost:27017/
# Atlas Connection String: mongodb+srv://gfusion333_db_user:password@cluster0.rldhwbm.mongodb.net/local

# %% [markdown]
# #### 2.1. Interogate the MongoDB Atlas instance for the databases it hosts.

# %%
client.list_database_names()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client.list_database_names()
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2385, in MongoClient.list_database_names(self, session, comment)
#    2368 def list_database_names(
#    2369     self,
#    2370     session: Optional[client_session.ClientSession] = None,
#    2371     comment: Optional[Any] = None,
#    2372 ) -> list[str]:
#    2373     """Get a list of the names of all databases on the connected server.
#    2374
#    2375     :param session: a
#    (...)
#    2383     .. versionadded:: 3.6
#    2384     """
# -> 2385     res = self._list_databases(session, nameOnly=True, comment=comment)
#    2386     return [doc["name"] for doc in res]
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2325, in MongoClient._list_databases(self, session, comment, **kwargs)
#    2323     cmd["comment"] = comment
#    2324 admin = self._database_default_options("admin")
# -> 2325 res = admin._retryable_read_command(cmd, session=session, operation=_Op.LIST_DATABASES)
#    2326 # listDatabases doesn't return a cursor (yet). Fake one.
#    2327 cursor = {
#    2328     "id": 0,
#    2329     "firstBatch": res["databases"],
#    2330     "ns": "admin.$cmd",
#    2331 }
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/database.py:1074, in Database._retryable_read_command(self, command, operation, session)
#    1061 def _cmd(
#    1062     session: Optional[ClientSession],
#    1063     _server: Server,
#    1064     conn: Connection,
#    1065     read_preference: _ServerMode,
#    1066 ) -> dict[str, Any]:
#    1067     return self._command(
#    1068         conn,
#    1069         command,
#    1070         read_preference=read_preference,
#    1071         session=session,
#    1072     )
# -> 1074 return self._client._retryable_read(_cmd, read_preference, session, operation)
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2048, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
#    2047 with self._tmp_session(session) as s:
# -> 2048     return self._retry_internal(
#    2049         func,
#    2050         s,
#    2051         None,
#    2052         operation,
#    2053         is_read=True,
#    2054         address=address,
#    2055         read_pref=read_pref,
#    2056         retryable=retryable,
#    2057         operation_id=operation_id,
#    2058     )
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2908, in _ClientConnectionRetryable._read(self)
#    2903 def _read(self) -> T:
#    2904     """Wrapper method for read-type retryable client executions
#    2905
#    2906     :return: Output for func()'s call
#    2907     """
# -> 2908     self._server = self._get_server()
#    2909     assert self._read_pref is not None, "Read Preference required on read calls"
#    2910     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2911         conn,
#    2912         read_pref,
#    2913     ):
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2856, in _ClientConnectionRetryable._get_server(self)
#    2851 def _get_server(self) -> Server:
#    2852     """Retrieves a server object based on provided object context
#    2853
#    2854     :return: Abstraction to connect to server
#    2855     """
# -> 2856     return self._client._select_server(
#    2857         self._server_selector,
#    2858         self._session,
#    2859         self._operation,
#    2860         address=self._address,
#    2861         deprioritized_servers=self._deprioritized_servers,
#    2862         operation_id=self._operation_id,
#    2863     )
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/topology.py:428, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     418 def select_server(
#     419     self,
#     420     selector: Callable[[Selection], Selection],
#    (...)
#     425     operation_id: Optional[int] = None,
#     426 ) -> Server:
#     427     """Like select_servers, but choose a random server if several match."""
# --> 428     server = self._select_server(
#     429         selector,
#     430         operation,
#     431         server_selection_timeout,
#     432         address,
#     433         deprioritized_servers,
#     434         operation_id=operation_id,
#     435     )
#     436     if _csot.get_timeout():
#     437         _csot.set_rtt(server.description.min_round_trip_time)
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/topology.py:402, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     393 def _select_server(
#     394     self,
#     395     selector: Callable[[Selection], Selection],
#    (...)
#     400     operation_id: Optional[int] = None,
#     401 ) -> Server:
# --> 402     servers = self.select_servers(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         operation_id,
#     408         deprioritized_servers,
#     409     )
#     410     if len(servers) == 1:
#     411         return servers[0]
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/topology.py:298, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     295     self.cleanup_monitors()
#     297 with self._lock:
# --> 298     server_descriptions = self._select_servers_loop(
#     299         selector,
#     300         server_timeout,
#     301         operation,
#     302         operation_id,
#     303         address,
#     304         deprioritized_servers=deprioritized_servers,
#     305     )
#     307     return [
#     308         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     309     ]
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/topology.py:359, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     348     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     349         _debug_log(
#     350             _SERVER_SELECTION_LOGGER,
#     351             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     357             failure=self._error_message(selector),
#     358         )
# --> 359     raise ServerSelectionTimeoutError(
#     360         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361     )
#     363 if not logged_waiting:
#     364     _debug_log(
#     365         _SERVER_SELECTION_LOGGER,
#     366         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     372         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     373     )
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-g2l6jz5-shard-00-00.rldhwbm.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-g2l6jz5-shard-00-02.rldhwbm.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-g2l6jz5-shard-00-01.rldhwbm.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 69b8590766487f6bbb3c484a, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-g2l6jz5-shard-00-00.rldhwbm.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-g2l6jz5-shard-00-00.rldhwbm.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>, <ServerDescription ('ac-g2l6jz5-shard-00-01.rldhwbm.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-g2l6jz5-shard-00-01.rldhwbm.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>, <ServerDescription ('ac-g2l6jz5-shard-00-02.rldhwbm.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-g2l6jz5-shard-00-02.rldhwbm.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>]>

# %% [markdown]
# #### 2.2. Connect to the "*sample_training*" database, and interogate it for the the collections it contains.

# %%
db_name = "sample_training"

db = client[db_name]
db.list_collection_names()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[5], line 4
#       1 db_name = "sample_training"
#       3 db = client[db_name]
# ----> 4 db.list_collection_names()
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/database.py:1241, in Database.list_collection_names(self, session, filter, comment, **kwargs)
#    1209 def list_collection_names(
#    1210     self,
#    1211     session: Optional[ClientSession] = None,
#    (...)
#    1214     **kwargs: Any,
#    1215 ) -> list[str]:
#    1216     """Get a list of all the collection names in this database.
#    1217
#    1218     For example, to list all non-system collections::
#    (...)
#    1239     .. versionadded:: 3.6
#    1240     """
# -> 1241     return self._list_collection_names(session, filter, comment, **kwargs)
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/database.py:1206, in Database._list_collection_names(self, session, filter, comment, **kwargs)
#    1202     if not filter or (len(filter) == 1 and "name" in filter):
#    1203         kwargs["nameOnly"] = True
#    1205 return [
# -> 1206     result["name"] for result in self._list_collections_helper(session=session, **kwargs)
#    1207 ]
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/database.py:1144, in Database._list_collections_helper(self, session, filter, comment, **kwargs)
#    1136 def _cmd(
#    1137     session: Optional[ClientSession],
#    1138     _server: Server,
#    1139     conn: Connection,
#    1140     read_preference: _ServerMode,
#    1141 ) -> CommandCursor[MutableMapping[str, Any]]:
#    1142     return self._list_collections(conn, session, read_preference=read_preference, **kwargs)
# -> 1144 return self._client._retryable_read(
#    1145     _cmd, read_pref, session, operation=_Op.LIST_COLLECTIONS
#    1146 )
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2048, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2044 retryable = bool(
#    2045     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046 )
#    2047 with self._tmp_session(session) as s:
# -> 2048     return self._retry_internal(
#    2049         func,
#    2050         s,
#    2051         None,
#    2052         operation,
#    2053         is_read=True,
#    2054         address=address,
#    2055         read_pref=read_pref,
#    2056         retryable=retryable,
#    2057         operation_id=operation_id,
#    2058     )
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2763, in _ClientConnectionRetryable.run(self)
#    2761 self._check_last_error(check_csot=True)
#    2762 try:
# -> 2763     return self._read() if self._is_read else self._write()
#    2764 except ServerSelectionTimeoutError:
#    2765     # The application may think the write was never attempted
#    2766     # if we raise ServerSelectionTimeoutError on the retry
#    2767     # attempt. Raise the original exception instead.
#    2768     self._check_last_error()
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2908, in _ClientConnectionRetryable._read(self)
#    2903 def _read(self) -> T:
#    2904     """Wrapper method for read-type retryable client executions
#    2905
#    2906     :return: Output for func()'s call
#    2907     """
# -> 2908     self._server = self._get_server()
#    2909     assert self._read_pref is not None, "Read Preference required on read calls"
#    2910     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2911         conn,
#    2912         read_pref,
#    2913     ):
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:2856, in _ClientConnectionRetryable._get_server(self)
#    2851 def _get_server(self) -> Server:
#    2852     """Retrieves a server object based on provided object context
#    2853
#    2854     :return: Abstraction to connect to server
#    2855     """
# -> 2856     return self._client._select_server(
#    2857         self._server_selector,
#    2858         self._session,
#    2859         self._operation,
#    2860         address=self._address,
#    2861         deprioritized_servers=self._deprioritized_servers,
#    2862         operation_id=self._operation_id,
#    2863     )
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/mongo_client.py:1833, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832     else:
# -> 1833         server = topology.select_server(
#    1834             server_selector,
#    1835             operation,
#    1836             deprioritized_servers=deprioritized_servers,
#    1837             operation_id=operation_id,
#    1838         )
#    1839     return server
#    1840 except PyMongoError as exc:
#    1841     # Server selection errors in a transaction are transient.
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/topology.py:428, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     418 def select_server(
#     419     self,
#     420     selector: Callable[[Selection], Selection],
#    (...)
#     425     operation_id: Optional[int] = None,
#     426 ) -> Server:
#     427     """Like select_servers, but choose a random server if several match."""
# --> 428     server = self._select_server(
#     429         selector,
#     430         operation,
#     431         server_selection_timeout,
#     432         address,
#     433         deprioritized_servers,
#     434         operation_id=operation_id,
#     435     )
#     436     if _csot.get_timeout():
#     437         _csot.set_rtt(server.description.min_round_trip_time)
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/topology.py:402, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     393 def _select_server(
#     394     self,
#     395     selector: Callable[[Selection], Selection],
#    (...)
#     400     operation_id: Optional[int] = None,
#     401 ) -> Server:
# --> 402     servers = self.select_servers(
#     403         selector,
#     404         operation,
#     405         server_selection_timeout,
#     406         address,
#     407         operation_id,
#     408         deprioritized_servers,
#     409     )
#     410     if len(servers) == 1:
#     411         return servers[0]
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/topology.py:298, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     295     self.cleanup_monitors()
#     297 with self._lock:
# --> 298     server_descriptions = self._select_servers_loop(
#     299         selector,
#     300         server_timeout,
#     301         operation,
#     302         operation_id,
#     303         address,
#     304         deprioritized_servers=deprioritized_servers,
#     305     )
#     307     return [
#     308         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     309     ]
#
# File /opt/anaconda3/envs/pysparkenv/lib/python3.12/site-packages/pymongo/synchronous/topology.py:359, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     348     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     349         _debug_log(
#     350             _SERVER_SELECTION_LOGGER,
#     351             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     357             failure=self._error_message(selector),
#     358         )
# --> 359     raise ServerSelectionTimeoutError(
#     360         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361     )
#     363 if not logged_waiting:
#     364     _debug_log(
#     365         _SERVER_SELECTION_LOGGER,
#     366         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     372         remainingTimeMS=int(1000 * (end_time - time.monotonic())),
#     373     )
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-g2l6jz5-shard-00-00.rldhwbm.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-g2l6jz5-shard-00-02.rldhwbm.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-g2l6jz5-shard-00-01.rldhwbm.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 69b8590766487f6bbb3c484a, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-g2l6jz5-shard-00-00.rldhwbm.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-g2l6jz5-shard-00-00.rldhwbm.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>, <ServerDescription ('ac-g2l6jz5-shard-00-01.rldhwbm.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-g2l6jz5-shard-00-01.rldhwbm.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>, <ServerDescription ('ac-g2l6jz5-shard-00-02.rldhwbm.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-g2l6jz5-shard-00-02.rldhwbm.mongodb.net:27017: [('SSL routines', '', 'tlsv1 alert internal error')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)")>]>

# %% [markdown]
# #### 2.3. Connect to the **trips** collection where we will be exploring a variety of querying techniques.
# For example, the following query makes use of the **find_one()** method to select the first document in the collection for the purpose of inspecting the structure and contents of a sample document.  Because each document may have a different schema, this single document can only give us a partial understanding of what the collection may contain. Notice that passing the *collection name* to the *database* object reference **db[  ]** returns a reference to the *collection* object.

# %%
collection = "trips"

trips = db[collection]
trips.find_one()

# %% [markdown]
# ### 3.0. Using the MongoDB Query Language (MQL)
#
# The **find()** method returns a **cursor** containing all documents from the **collection** that match the filtering **conditions** that were provided. A **cursor** is required to *iterate* over the results because MongoDB manages **collections of documents** that contain **fields** rather than **tables of rows** that contain **columns** as we saw when studying relational database management systems like Microsoft SQL Server, Oracle and MySQL.
#
# #### 3.1. Specifying Conditions and Projections
# When querying MongoDB, the **find()** method of the **collection** object accepts two possible parameters. First, one or more **conditions** are used to *filter* or restrict the documents that are returned. Second, and optionally, a **projection** can be defined to control which **fields** that are returned. The **conditions** are the equivalent of a SQL query's *ON, WHERE* and *HAVING* clauses, and the **projection** is the equivalent of a SQL query's *SELECT* list.
#
# The MongoDB (JSON) query syntax includes numerous conditional operators, all of which begin with the **\$** character (e.g., **\$lt** *(less than)*, **\$gt** *(greater than)*, **\$lte** *(less than or equal to)*, **\$gte** *(greater than or equal to)*). These operators can be used either alone or in concert with one another to perform exact matches and/or range matches.
#
# For example, the following query **excludes** the *_id* field and **includes** the *tripduration, bikeid and birth year* fields where the **tripduration** is *greater than* 90 seconds and *less than* 100 seconds, and the **birth year** is greater than or equal to *1970*. The results are then **sorted** by **trip duration** in descending order.

# %%
# The SELECT list -----------------------------------------------
projection = {"_id": 0, "tripduration": 1, "bikeid": 1, "birth year": 1}

# The WHERE clause ----------------------------------------------
conditions = {"tripduration":{"$gt": 90, "$lt": 100}, "birth year":{"$gte": 1970}}

# The ORDER BY clause -------------------------------------------
orderby = [("tripduration", -1)]

for trip in trips.find(conditions, projection).sort(orderby):
    print(trip)

# %% [markdown]
# ##### 3.1.1. Using the Pandas DataFrame
# To make interacting with the *collection of documents* that are returned by the **find()** method much easier, we can use the Python **list()** method to *package* each document returned by the cursor into a Python **list** object that can then be passed to the *Pandas* **DataFrame()** constructor. This technique is very usefull for interacting with document collections having a common subset of fields available for **projection**.

# %%
df = pd.DataFrame( list( db.trips.find(conditions, projection).sort(orderby) ) )
df

# %% [markdown]
# #### 3.1.2. Using Logical Operators
# In structuring a list of **conditions**, it is implicit that the conditions are **cumulative**. In other words, each conditional expression builds upon all former conditions using **AND** logical operation.  It is also possible to express **OR** logical operation using either the **\$in**, or **\$or** operators.
#
# First, the **\$in** operator functions identically to the **IN** operator of the Structured Query Language (SQL) that's used to interact with relational database management systems like Microsoft SQL Server, Oracle, MySQL and PostgreSQL in that its functionality enables matching multiple values for a single key (field).  In the following query, all documents are returned where the **birth year** field contains either the value **1936, 1939** *or* **1943**.

# %%
conditions = {"birth year" : {"$in" : [1936, 1939, 1943]}}
    
df = pd.DataFrame( list(db.trips.find(conditions, projection).sort(orderby)) )
df

# %% [markdown]
# Conversely, the **\$nin** operator is used to express **NOT IN** logical operation. The following query returns all documents where the **birth year** field contains any values other than *1960, 1970* **or** *1980*. Also, here we rely on the **head()** function of the Pandas DataFrame object to specify the number of documents to return from the top *(head)* of the result-set; the default number of rows is 5.

# %%
conditions = {"birth year" : {"$nin" : [1960, 1970, 1980]}}

df = pd.DataFrame( list(db.trips.find(conditions, projection).sort(orderby) ) )
df.head()

# %% [markdown]
# Where it becomes necessary to match values regarding multiple keys (fields), the **\$or** operator can be used in a manner that's identical to the **OR** operator of the **SQL** language. The following query returns all documents where the **birth year** field contains the value *1988* **OR** the **start station id** field contains the value contains the value *270*.  We also illustrate the **limit()** function being used to return a specified number of documents from the **top** of the result-set.

# %%
projection = {"_id": 0, "start station id": 1, "birth year": 1, "tripduration": 1}
conditions = {"$or" : [{"birth year" : 1988}, {"start station id" : 270}]}
num_rows = 7

df = pd.DataFrame( list(db.trips.find(conditions, projection).sort(orderby).limit(num_rows) ) )
df

# %% [markdown]
# What's more, the **\$not** metaconditional operator can be used in concert with many other conditionals for the sake of *negating* the expression.

# %%
condition = {"birth year" : {"$not" : {"$in" : [1960, 1965, 1970, 1975, 1980]}}}
projection = {"_id": 0, "usertype": 1, "birth year": 1}

df = pd.DataFrame( list(db.trips.find(conditions, projection).sort(orderby).limit(num_rows) ) )
df

# %% [markdown]
# ### 4.0. Using the MongoDB Aggregation Framework
# The aggregation framework enables using a *pipeline* construct where the result of each element is passed to the next.
#
# #### 4.1. The Match and Project Stages:
# In our first task we illustrate simply duplicating the behavior of the *MongoDB Query Language (MQL)* queries we've already seen. The following cell demonstrates how the **\$project** operator works in concert with the **\$match** operator to return the same results as an MQL query that specifies returning the **start station id** and **birth year** fields **where** the **birth year** is equal to **1941**.

# %%
df = pd.DataFrame( list(
    
    db.trips.aggregate([
        {"$project": {"start station id": 1, "birth year": 1, "_id": 0}},
        {"$match": {"birth year": 1941}}
    ])
    
))
df

# %% [markdown]
# #### 4.2. The Group Stage
# While the code listing above doesn't illustrate the power of the aggregation framework, the following demonstrates how the aggregation framework enables **grouping** document collections by specific criteria.
# - In the first example below we demonstrate how to enumerate all the unique values in the **birth year** field greater than or equal to 1990
# - Then we show how to calculate the **count** of documents **having** the same **birth year**, returning only the **top 10 birth years** with the greatest **count**.

# %%
df = pd.DataFrame( list(
    
    db.trips.aggregate([
        {"$project": {"birth year": 1, "_id": 0}},
        {"$match": {"birth year": {"$gte": 1990}}},
        {"$group": {"_id": "$birth year"} 
        }
    ])
    
))
df

# %%
df = pd.DataFrame( list(
    
    db.trips.aggregate([
        {"$project": {"birth year": 1, "_id": 0}},
        {"$match": {"birth year": {"$gte": 1990}}},
        {"$group": {"_id": "$birth year",
                    "count": {"$sum": 1}
                   }
        },
        {"$sort": {"count": -1}},
        {"$limit": 10}
    ])
    
))
df
